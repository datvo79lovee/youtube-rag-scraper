# %%
from langchain_core.documents import Document
import json

docs = []

with open('/Users/carwyn/Downloads/transcript_v3.jsonl') as f:
    for line in f:
        chunk = json.loads(line)

        doc = Document(
            page_content=chunk["chunk_text"],
            metadata={
                "video_id": chunk["video_id"],
                "title": chunk["title"],
                "course": chunk["course"],
                "start_time": chunk["start_time"],
                "end_time": chunk["end_time"],
                "duration": chunk["duration"],
                "source": chunk["source"],
                "chunk_type": chunk["chunk_type"],
                "token_count": chunk["token_count"],
            }
        )

        docs.append(doc)
print("Số lượng document:", len(docs))

print("\nSample 1 document:")
print(docs[0].page_content[:200])  # xem 200 ký tự đầu
print(docs[0].metadata)
# Out:
# Số lượng document: 10720
#
# Sample 1 document:
# we spent sometimes like two months training the bots on thousands of CPUs, terabytes of memory sometimes But when it came time to actually play against the humans, they would act almost instantly It w
# {'video_id': 'phWxl0nkgKk', 'title': 'Stanford CS25: V2 I Strategic Games', 'course': 'CS25_Transformers', 'start_time': 5.88, 'end_time': 67.21, 'duration': 61.33, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 237}

# %%
query = "vector "
for doc in docs:
    if query.lower() in doc.page_content.lower():
        print(doc.page_content)
        print(doc.metadata)
# Out:
# for us this was how we put together the final MedPaLM model We sorry, go ahead Sorry I'll let you finish cool this was how we put together the final MedPaLM model we used instructions and exemplars from a panel of expert clinicians And these are in the order of hundreds, not thousands and tens of thousands and you see a few examples over there There's an instruction, followed by a model answer followed by an explanation And we use that to learn the prompt practice And so the final MedPaLM model is basically all of FLANPaLM plus these additional prompt vector parameters which are used to align the model to the requirements of the medical domain And why this works well is because as we have seen before the model already has medical knowledge encoded in it All we need is to teach the model how to use it properly in the given application setting and that's what these parameters do for us the question I wanted to ask is, nowadays you've probably seen a lot about online chat
# {'video_id': 'nz7_wg5iOlA', 'title': 'Stanford CS25: V2 I Biomedical Transformers', 'course': 'CS25_Transformers', 'start_time': 1440.59, 'end_time': 1498.385, 'duration': 57.795, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 234}
# to part of the circuit there first, I'm going to give an overview of Sparse Distributed Memory I have a transformer attention summary but I assume that you guys already know all of that We can get there and then decide how deep we want to go into it I'll then talk about how actually attention approximates Interpret the transformer more broadly, and then hopefully there's time to go into SDM's biological plausibility Also, I'm going to keep everything high level visual intuition, and then go into the math But stop me, and please ask questions, literally, whenever Sparse Distributed Memory is motivated by the question of how the brain can read and write memories in order to later retrieve the correct one And some considerations that it takes into account are high memory capacity, robustness to query noise biological plausibility, and some notion of fault tolerance SDM is unique from other associative memory models that you may be familiar with, like hopfield networks Insomuch as it's sparse, so it operates at a very high dimensional vector space
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 78.79, 'end_time': 145.84, 'duration': 67.05, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 231}
# and the neurons that exist in this space only occupy a very small portion of possible locations It's also distributed, so all read and write operations apply to all nearby neurons It is actually, as a side note, hopfield networks if you're familiar with them, are a special case of sparse distributed memory I'm not going to go deep into that now but I have a blog post on it first, we're going to look at the write operation for sparse distributed memory We're in this high dimensional binary vector space We're using hamming distance as our metric for now we'll move to continuous later And we have this green pattern, which is represented by the solid dot, and the hollow circles are these hypothetical neurons Also, think of everything quite abstractly and then we'll map to biology later this pattern has a write radius which is some hamming distance It activates all of the neurons within that hamming distance and then here I just denote that each of those neurons are now storing that green pattern and the green pattern has disappeared
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 145.84, 'end_time': 216.13, 'duration': 70.29, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 237}
# to the next part of the network And the cat value vector, hypothetically contains a superposition of other animals like mice and maybe words that rhyme with mat And the sat vector also contains things that are sat on, including mat And so what you actually get from the value vectors of paying attention to cat and sat are like, 3 times mat plus 1 times mouse plus 1 times sofa This is again, like, a totally hypothetical example but I'm trying to make the point that you can extract from your value vectors things useful for predicting the next token by paying attention to specific keys and I guess another thing here is like what you pay attention to cat and stat might be different from what you're actually extracting If you're paying attention to your keys but you're getting your value vectors out here is the full attention equation The top line, I'm separating out the projection matrices W subscript V and q, and then the second one I just collapsed them into the equation you are going to see
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 562.22, 'end_time': 630.6, 'duration': 68.38, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
# And yeah, so breaking this apart the first step here is we compare we do a dot product between our query vector and our keys This should actually be a small q and capital Q. Sorry for that And so yeah, we're doing this dot product between them to see get a notion of similarity We then apply the softmax operation which is an exponential over a sum of exponentials The way to think of the softmax is it just makes large values larger And this will be important for the relation to SDM, so I'll spend a minute on it At the top here, I have some hypothetical items index from 0 to 9 And then the values for each of those items In the second row, I just do like a normal normalization of them And so the top item goes to a 30 value But if I instead do a softmax, it depends on the beta, the softmax But the value becomes 0.6 it just it makes your distributions peak year is kind of one way of thinking of it
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 630.6, 'end_time': 696.58, 'duration': 65.98, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 237}
# And the value for what it should actually store, and This is called hetero associative mapping And then, once you're reading from the system you also have your query come in here, activate neurons and those neurons then output whatever they stored And the neurons vector is this particular column that it's stored And it's, as a reminder, it's storing patterns in superposition And then, it will dump whatever it stored across these output lines And then, you have this G majority bit operation to convert to a 0 or 1, decide if the neuron is going to fire or not And so, here is the same circuit but where I overlay cell types in the cerebellum And so I'll come back to this slide because most people probably aren't familiar with cerebellar circuitry Let me just it's in water the way that the cerebell is pretty homogeneous, in that it follows this pattern throughout Also fun fact, 70 of all neurons in the brain are in the cerebellum They're small, so you wouldn't know it but the cerebellum is very underappreciated
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 1646.05, 'end_time': 1726.65, 'duration': 80.6, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
# that it's much more accurate But it seems like this also applies to next word prediction Like we have fMRI data for this A neuroscientist once said to me that a dirty little secret of fMRI is that the cerebellum lights up for everything going back to this circuit here, then Timescales, are these operating again how long is the information stored and retrieved Do we have any idea about this Like it's just like a couple of milliseconds or is this information more persistent the main theory is that you have updating through timedependent plasticity, where your climbing fiber will either which is doing what you want right then will fire either just before or just after your granule cells fire And so that, then, updates the purkinje cell synapses for long term depression or potentiation whatever timescale that's happening on The climbing fiber makes very large vector potentials or it leads to very large vector potentials within the cell And so I do think you could get pretty fast synaptic updates And they're also persistent for a long time
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 1847.06, 'end_time': 1924.35, 'duration': 77.29, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 235}
# I think so, yeah The synapses are steady for like the rest of your life what's really unique about this circuit is the fact that you have these two orthogonal inputs, where you have the mossy fibers bringing information And then it's decided if the neurons are going to fire or not But then the totally separate fiber lines that can update specific neurons and what they're storing and will later output And then, the purkinje cell is so important it's kind of doing this pooling across every single neuron And each neuron, remember, it's storing a vector this way And so the purkinje cell is doing element wise, summation and then deciding whether it fires or not And this allows for you to store your vectors in superposition and then later denoise them
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 1924.35, 'end_time': 1971.13, 'duration': 46.78, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 174}
# which you can think of as like separate attention heads in a way I don't want to take that analogy too far but it is somewhat interesting the way you relate this is in attention you have your beta coefficient That is an effective beta coefficient because the vector norms of your keys and queries aren't constrained That corresponds to a Hamming distance And here, that corresponds to the number of neurons that are on for any given input And the Hamming distance you want I had that the slide before, the Hamming distance you want depends upon what you're actually trying to do And if you're not trying to store that many memories for example, you can have a higher Hamming distance because you can get a higher fidelity calculation for the number of neurons in that noisy intersection Cool, yeah, thanks a lot
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 2488.92, 'end_time': 2548.21, 'duration': 59.29, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 188}
# Sorry, I can't hear you, if you're asking a question How do I mute someone if they're Maybe type it in the chat if there is one Nice we got the hippocampus in the middle which is going to be our binding of the two of them together I'm going to step through each of these three parts on their own, and how they do the job that I've assigned to them And then, come back together and show the full model lateral entorhinal cortex encodes what you're seeing this is like these images, or the houses we were looking at before And that would just be some vector XT that's different a random vector, different for every signal The medial entorhinal cortex is the one that tells you where you are in space And it has the job of pathintegrating this means receiving a sequence of actions that you've taken in space, for example, went north, east and south, and telling you where in 2D space that you are somehow the bit that embeds the structure of the world
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 3633.13, 'end_time': 3698.16, 'duration': 65.03, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 234}
# And the way that we'll do that is this g of T this vector of activities in this brain area will be updated by a matrix that depends on the actions you've taken if you step north, you update the representation with the step north matrix And those matrices are going to have to obey some rules For example, if you step north and step south you haven't moved, and so the step north matrix the step south matrix, have to be inverses of one another that the activity stays the same and represents the structure of the world somehow that's the world structure part Finally, the memory, because we have to memorize which things we found at which positions going to happen in the hippocampus and that's going to be through a version of these things called the Hopfield networks, that you heard mentioned in the last talk this is like a content addressable memory and it's biologically plausible, this claim The way it works is you have a set of activities, p which are the activities of all these neurons
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 3698.16, 'end_time': 3752.21, 'duration': 54.05, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
# of petroassociated, so how are you The memories that we're going to put in the patterns, let's say, chi mu is going to be some outer product of the position at a given time And the flattened so yeah, take the outer product of those, so every element in x gets the every element of g Front nose out, and that's your vector that goes Does that makes sense Sorry, I should have put that on and then you do the same operation except you flatten with an identity in the let's say you're at a position you want to print what you see You set x to the identity, you do this operation it creates a very big vector from g You put that in, and you let it run it's dynamics and it recalls the pattern And you learn a network that like traces out the x from that And the figures you show, if you go down a bit it's hard to see, but what's on the xaxis and what's like what are you training a Hopfield network with this
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 4121.529, 'end_time': 4184.75, 'duration': 63.221, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 237}
# But then, you're and then you have some results looking at activations these are recordings in the brain, or No, these are actually in TEM this is the left ones are neurons in the G section in the medial entorhinal cortex part of TEM as you vary position Cool, OK and we're going to get my last section is about how these TEM is like we'll get to hopefully it will be clear the links between the two after that we're happy with that, though, hopefully Cool, term is approximately equal to transformer, yeah you seem to know all of this But I guess my notation, at least we can clarify that You got your data, which is maybe your tokens coming in and you got your positional embedding And the positional embedding will play a very big role here That's the E, and together, they make this vector H And these arrive over time and you got your attention updates that you see some similarity between the key and the query and then you add up weighted values with those similarities
# {'video_id': 'L4DC7e6g2iI', 'title': 'Stanford CS25: V2 I Neuroscience-Inspired Artificial Intelligence', 'course': 'CS25_Transformers', 'start_time': 4245.21, 'end_time': 4305.86, 'duration': 60.65, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
# And now for the retrieval process When Voyager is faced with a new task let's say craft iron pickaxe, we again use GPT 3.5 to generate a hint on how to solve the task and that is something like a natural language paragraph And then we embed that and use that as the query into the vector database, and we retrieve the skill from the library you can think of it as a kind of incontext replay buffer in the reinforcement learning literature And now, moving on to the third part We have another GPT4 that proposes a task to do given it's own capabilities at the moment And here, we give GPT4 a very highlevel kind of unsupervised objective, that is to obtain as many unique items as possible That is our highlevel directive And then GPT4 takes this directive and implements a curriculum of progressively harder challenges and more novel challenges to solve it's kind of like curiosity exploration, where it is called novelty search in the prior literature but implemented purely in context if you are listening, then assume the next example is fun
# {'video_id': 'wwQ1LQA3RCU', 'title': 'Stanford CS25: V3 I Generalist Agents in Open-Ended Worlds', 'course': 'CS25_Transformers', 'start_time': 1566.6, 'end_time': 1640.032, 'duration': 73.432, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 243}
# We were sequentially decoding the output lefttoright But also, we were reading the input sequentially you had to In order to produce the representation for the 10th word, you had to eat up the first word, the second word the third word that was really slow, and not the whole and another big problem with LSTMs were that you have this bottleneck that basically that contains all the information about your past you have to now crush you have to pack both longdistance interactions that you might have and local interactions through the single fixed vector that you need to transmit And sequentiality doesn't inhibits parallelism which means that you couldn't even read The encoder couldn't even read the sentence in parallel And of course, decoding was autoregressive you couldn't even write in parallel And convolutions were they were starting to emerge as a solution, largely They had been very successful in computer vision They had also figured out how to optimize them while how to make them how to train how to make them really fast on GPUs, where
# {'video_id': '1GbDTTK3aR4', 'title': 'Stanford CS25: V3 I How I Learned to Stop Worrying and Love the Transformer', 'course': 'CS25_Transformers', 'start_time': 761.708, 'end_time': 829.33, 'duration': 67.622, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 234}
# these are the bunches of tokens that just have very high intersimilarity They're likely to attend to each other How quickly can I approximate it without actually having to do the whole computation Two approaches In routing attention, you use vector quantization And in the LSH or the I forget what it's called I think I forgot the name of the paper But they used but in this paper, they used LSH And in the routing transformer, most layers were actually local The final layers, which typically are the ones that like to end up that end up doing modeling that end up modeling these longdistance relationships were the ones that actually used this contentbased, unstructured sparse attention And the results were the results were generally better And it's also interesting that maybe you can build we can build models with on very long sequences where most layers are fairly local And you have only a few layers that are actually doing these longdistance attentions Now, one of the bigger challenges there actually even though it ended up being
# {'video_id': '1GbDTTK3aR4', 'title': 'Stanford CS25: V3 I How I Learned to Stop Worrying and Love the Transformer', 'course': 'CS25_Transformers', 'start_time': 2543.2, 'end_time': 2608.17, 'duration': 64.97, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 232}
# then your posterior outputs should be conditionally independent of each other, right great point, and where do you get the latent space from from the encoder or whatever at the beginning Right, but there might be quite a few ways to translate something, right There's multiple so if there's only one mode, then yeah it's probably But if there's multiple ways of there's two things How much does the latent space actually carry, by the way is an important thing to ask How much does it actually carry Because it's not just one latent vector that you're transmitting every you're doing attention again and again but we took this approach, where we did precisely this We autoregressively generated tokens in a new vocabulary using vector quantization the conditional dependence was modeled in a latent space, where we discretized using vector quantization And then based on that, we generated everything conditioning, and that did work But again, so that did work in translation There were some funky issues there where the sequence of latent vectors were only effective were not effective if you learn directly
# {'video_id': '1GbDTTK3aR4', 'title': 'Stanford CS25: V3 I How I Learned to Stop Worrying and Love the Transformer', 'course': 'CS25_Transformers', 'start_time': 4601.9, 'end_time': 4683.025, 'duration': 81.125, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 239}
# have to answer if you want to design a system like this And then during test time, you have this entire system actually multiple models in a way that are working together there's also different things you can do there give it different indices during test time or manipulate how you're sampling, things like that the starting point for all of this stuff I think if you ask someone now, like, What is RAG they will think of this thing this is frozen RAG, basically There's no training here at all going back to this question of train time, test time there's only test time here Train time happens separately with these black box models that we don't necessarily have control over there's this document embedding model is whatever is currently at the top of some opensource leaderboard You use that oops, sorry to get some vectors that you then use to create this vector database And then the vector database just does search And it gives the information from the search to the language model
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 634.46, 'end_time': 699.78, 'duration': 65.32, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 228}
# And it just passes it as the context this only works because of incontext learning And I think as a machine learner myself this feels very inelegant what this lecture is about is can we do better than this frozen thing let's start from the left side of this if we want to outperform this frozen thing itself with just the vector database, what would that look like from a retrieval perspective And the starting point for everything retrieval is TFIDF Does everybody know what TFIDF is TFIDF is basically a sparse retrieval method where you have a score function that looks at documents and queries D and Q. And then there are basically two terms that matter One is the TF, the Term Frequency And the other is the IDF, the Inverse Document Frequency this inverse document frequency is actually a really nice idea from Karen Sparck Jones really underrated researcher She's done some amazing work But the basic idea is that you want to look at the words that are very special they don't occur in lots of different documents
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 699.78, 'end_time': 775.84, 'duration': 76.06, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
# And so the overlap between the word the doesn't really matter The occurs everywhere you want to have the special words that's what TFIDF does in a nutshell it gives you a score for document query overlap And then you can do all kinds of things here with how you weight it there's all these weird different parameters like this b and things like that that allow you to make it better than just having the TFIDF score there's a couple of tweaks you can do there BM25, actually, in case you're wondering stands for Best Match 25 I tried to discover where does the 25 actually come from That's because the preceding 24 experiments failed it's literally the 25th one that seemed to work and that's why it's called BM25 It's bizarre this is sparse retrieval It's just counting words you have this massive, massive vector of all these word occurrences It's sparse because most words never occur it's sort of like a vector of vocabulary size dimensions most of that is obviously zero that's actually a nice property
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 775.84, 'end_time': 847.16, 'duration': 71.32, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 234}
# They're dense now, no longer sparse they're much smaller in terms of dimensionality And the nice advantage of dense retrieval is that it's not really about specific words if there are synonyms, you can still find the relevant document, which you couldn't really do with a sparse representation that's really the advantage of dense is that you get semantic similarity you can do this over word embeddings that doesn't really work all that well But at the time that people started thinking about this BERT was already out there And BERT is really great for giving you a vector representation for an entire sequence of words a sentence representation or a passage representation there are all these cool systems like ORCA and DPR the Dense Passage Retriever, where they essentially use the retrieval as a latent variable in the system And the way to get the latent variable to work to be good enough, essentially to train the entire system is to pretrain the retriever on relevant information for archive, they do something called inverse close
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 918.29, 'end_time': 985.64, 'duration': 67.35, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 228}
# they do a close task where you want to find passages that are relevant to the preceding passage And then DPR, they just train it on the supervised thing But really, the core idea here is that, as you can see in this graph here you can do better than BM25 if you had lots of documents And the way you compute the score function is much simpler It's just the dot product the nice thing about dot products is that you can do them very, very efficiently on the GPU as well if what you're doing what you really want to get at is Maximum Inner Product Search, MIPS this is one of the core ideas of a lot of this stuff And you can do MIPS with ANN, Approximate Nearest Neighbor search And so there's this really brilliant piece of work out of FAIR for my colleagues at the time called FAISS, which really underlies all of these modern vector databases all the popular ones that are of reimplementations of this FAISS idea one is in like Rust one, is in Go
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 985.64, 'end_time': 1052.078, 'duration': 66.438, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 239}
# But it's all basically the same idea It's just FAISS And so FAISS really powers a lot of this stuff And whenever somebody tells you something about a vector database, just think about FAISS Very fast dot product obviously, you can go beyond dot product What is it What's FAISS What is FAISS it's an opensource library, Facebook AI Similarity Search No, so it's just basically off the shelf and algorithms there are all kinds of different I don't know if you do what product quantization is and things like that there are basically so you have a bunch of vectors And you can just compute the full dot product which is sort of inefficient what you can do is try to compress subspaces of the vector and then just look at the kind of centroids you can quantize subvectors of the full vector and then do much faster search over just the centroids It's a good question Any other questions
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 1052.078, 'end_time': 1123.96, 'duration': 71.882, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 209}
# But I think if we look at where the state of the art has been going now, one of the nice things about these vector databases is that they're super efficient dot product is much more efficient than this late interaction stuff especially if you do the approximate nearest neighbor search But there's been some really cool work things like SPLADE, they basically have sparse meat dense in a way one of the big problems as I said with sparse is that you can't really handle synonyms and things like that But what you could do is take a dense model like a BERT model look at this one word in your sequence try to see which other words fit in the same slot that gives you the synonyms now you can give all these synonyms to a sparse vector And then you can just do sparse dot product and so have a much, much more efficient way to do search without giving up on all the cool stuff that you get from a dense representation
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 1190.14, 'end_time': 1248.01, 'duration': 57.87, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 228}
# That's why hybrid is probably the way to go It's a good question Wait, with the dense things, it's contextualized embeddings But shouldn't it realize Apple, the company would be different from No, so if they were actually contextualized, then yes But very often, it's a frozen retrieval system That's one of the problems with all the frozen RAG stuff I might be missing something very basic here referring to the vectors that you're getting the Vectors that you're using is either the query or the And so the document and the query, they're the same they're either sparse, or they're dense if they're sparse, the components of the vector are literally the other words You just one penalized when you're to the thing that creates the embeddings How are you getting it's literally counts basically, it's one big matrix of documents as rows And the columns are the words in the documents And then you just count how often a word occurs in a document that's a sparse property of sparse You're also referring to and so in the field, we call
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 1392.1, 'end_time': 1482.86, 'duration': 90.76, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 237}
# problem in a sense of place and vector as opposed to specifically going for interpretation try to output a vector that's going to inner product with just the right maybe you can tune for a particular database I don't know exactly what I just described somebody asked like how do you actually so I said there are other ways to do this and then the question was how do you do that the way you do that is using reinforce there has been work on doing that some of the older papers were playing with this But one of the big problems with I think the REPLUG solution is more elegant for solving that problem because you actually use signal from the language model And if you just do reinforce, it's very high variance you're it's going to be super finicky if you don't want to destroy your index But people have tried it, yeah
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 3587.91, 'end_time': 3644.636, 'duration': 56.726, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 201}
# and InstructRetro is how can we instruct and fine tune an entire retrieval augmented system all the way into the retrieval step can we generate data so that also follows the instructions properly which currently doesn't happen in any of these model architectures And then finally, I think I would be remiss if I didn't really talk about what people call advanced RAGs like the developer community has been really doing some awesome stuff, so like frameworks like LlamaIndex, and LangChain And there's all these open source vector databases like Chroma and Weaviate And they're all about making RAGs really easy But this is all frozen RAG, right But even with frozen RAG, you can really do incredible things we mentioned some of these already childparent recursive retriever you find small parts and then you give the big parts around it to the language model You can do hybrid search where we use reciprocal rank fusion we have different search results that we didn't combine before we give the final thing to the language model There's zero shot like large language model reranker
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 3769.97, 'end_time': 3833.82, 'duration': 63.85, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 237}
# have to pretrain, so but maybe there's something wrong with how we do that What do scaling laws look like I think there's a really interesting question here around if I have a huge index and a very rich encoder of all the information in that index, maybe I can move basically decouple all the memorization to this index I have a language model that doesn't know anything it just speaks English, it just reasons on top of it It has no knowledge because that always comes from this retriever If you can do something like that then you get very interesting scaling trade offs, right you can have a tiny language model and do your retrieval to do a lot of the heavy lifting with your retrieval which is nice because that's a cached computation, right you can just you already have the embeddings you just need to do the dot product it's much more efficient than selfattention in the language model Can we move beyond by encoders vector databases, I like people who build vector databases, but I'm not sure
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 3900.535, 'end_time': 3958.54, 'duration': 58.005, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
# how long we're going to keep vector databases Because I think reranker is probably work just as well And BM25 is much more efficient than a vector database I don't really see why we need dedicated vector databases And so what we're seeing but maybe this is a bit of a critique of maybe Silicon Valley investment strategies and things like that, but a lot of these vector database companies are basically becoming database companies now they are adding all this spark stuff because the dense thing is not enough And as it turns out, there are a lot of pretty good sparse databases out there already like Postgres and things like that And they're also all adding vectors to their databases I think that's all going to coalesce into databases I think there are some interesting things to look at for the data alluding to this instruction problem can we generate much better data for training RAG systems synthetically And then I think there's this massive open question around how we actually measure whether the system is any good
# {'video_id': 'mE7IDf2SmJg', 'title': 'Stanford CS25: V3 I Retrieval Augmented Language Models', 'course': 'CS25_Transformers', 'start_time': 3958.54, 'end_time': 4029.97, 'duration': 71.43, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 234}
# sort of understanding what you were saying these were like the earliest forms of NLP and they were mostly rulebased approaches where you're trying to understand the patterns in sentences, patterns and what words are said And these were the earliest linguistic foundations learning about semantic parsing Then we needed to go on to understand more deeper meanings within words we come up with things called Word Embeddings, which are vector representations of words and they gave us different semantic meanings in words that we weren't able to understand before we create vector representations words that are similar appear closer togeth in this vector space, and we're able to learn different types of meanings And then these examples I have here are word two, vec, love bird, Elmo These are different types of word embeddings and they sort of evolve word two vector is like a local context word embedding, word glove, we get like global context within documents now that we have ways to represent words into vector representations, now we can turn them into put them into our models and do different types
# {'video_id': 'fKMB5UlVY1E', 'title': 'Stanford CS25: V4 I Overview of Transformers', 'course': 'CS25_Transformers', 'start_time': 474.33, 'end_time': 544.18, 'duration': 69.85, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 240}
# of tasks, such as questionanswering, or text summarization, or sentence completion, machine translation And we develop different types of models that are able to do that here we have RNNs, LSTMs that are used for different translation tasks And so since we have our models, the now new challenge becomes to understand how we can do these tasks better thanks, Seonghee she talked about sequence to sequence models Those are naturally just inefficient as well as ineffective for many ways You cannot parallelize because it depends on recurrence It relies on maintaining a hidden context vector of all the previous words and their information you couldn't parallelize and it was inefficient and not very effective this led to what is now known as attention as well as transformers as the word kind of infers, attention means being able to focus attention to different parts of something In this case, a piece of text this is done by using a set of parameters called weights that basically determine how much attention to should be paid to each input at each time step
# {'video_id': 'fKMB5UlVY1E', 'title': 'Stanford CS25: V4 I Overview of Transformers', 'course': 'CS25_Transformers', 'start_time': 544.18, 'end_time': 611.75, 'duration': 67.57, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 235}
# And right now how we're doing this is like through embeddings you can take any PDF or any modality you care about convert that to embeddings using an embedding model And store that embedding in a vector database And later when we actually care about doing any sort of access to the memory, you can load the relevant part of the embedding put that in as part of your instruction and feed that to the model And so this is how we are thinking about memory with AI, this space And then you essentially have the retrieval models which are acting as a function to store and retrieve memory And the embeddings becomes the layer of the it's basically the format you're using to encode the memory in this case There's still a lot of open questions because how this works right now is you just do simple kNN it's very simple nearest neighbor search, which is not efficient, it doesn't really generalize doesn't scale And so there's a lot of things you can think about, especially hierarchy, temporal coherence
# {'video_id': 'fKMB5UlVY1E', 'title': 'Stanford CS25: V4 I Overview of Transformers', 'course': 'CS25_Transformers', 'start_time': 3784.24, 'end_time': 3845.38, 'duration': 61.14, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 234}
# here I'm representing it with this a vector of size three or something And then we have to let them take the dot product this lines represent which element can talk to which element, other elements And here because it's an input, we take what is called a bidirectional attention any token can talk to any other token And then we have this MLP or feedforward layer which is per token, it doesn't have any interaction we just do some multiplication just because we can do it And then that's one layer, and we repeat that n times and that's just the transformer encoder And at the end, what you get is the sequence of vectors each representing the sequence element in this case a word that's the output of this encoder Now, let's look at the decoder, which is similarly shaped stack of layers here we put in as an input what the answer should be here, BOS, is the beginning of sequence and then das ist gut, I don't know how to pronounce it
# {'video_id': '3gb-ZkVRemQ', 'title': 'Stanford CS25: V4 I Jason Wei & Hyung Won Chung of OpenAI', 'course': 'CS25_Transformers', 'start_time': 2897.63, 'end_time': 2961.47, 'duration': 63.84, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 228}
# representation of each sequence in the output decod should attend to some of them in the encoder, and that is done In particular the design feature which is interesting is that all the layers in the decod attend to the final layer output of the encoder and we'll come back to the implication of this design that's that And now, move on to the second type of architecture which is encoderonly We'll spend a little bit of time here again, we have to we have the same input, and we go through a similar structure And then in this case, the final output is a single vector Regardless of the length of the sequence we just get a single vector And that is that represent the input sequence, that's a dense vector representation And then let's say we do some kind of a sentiment analysis we run through a task specific linear lay to map it to classification label positive or negative probabilities here And that's required for all these task specific cases And this is kind of popularized by Bert
# {'video_id': '3gb-ZkVRemQ', 'title': 'Stanford CS25: V4 I Jason Wei & Hyung Won Chung of OpenAI', 'course': 'CS25_Transformers', 'start_time': 3025.13, 'end_time': 3090.02, 'duration': 64.89, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 235}
# by which selfattention creates feature weights It really just computes similarity in that shared space Large and similar inner products really just result in strongly weighted features it's up to that dimensionalization to produce good similarities for whatever purpose your prediction requires However, an alternative strategy for future waits might ask given a basis in other words, you're stuck with your low dimensional vectors What is the optimal way to convert those comparisons of the vectors you're looking at by a matrix transformation to modify the vector similarities that you are stuck with that correspond to the best weights for features In other words, treat this as a feedforward lay to produce selfattention weights as opposed to try and transform to some basis that produces good feature weights The use of this modified selfattention mechanism will be part and parcel the substance of this talk
# {'video_id': 'zL9B3eXq0gY', 'title': 'Stanford CS25: V4 I Transformers that Transform Well Enough to Support Near-Shallow Architectures', 'course': 'CS25_Transformers', 'start_time': 252.77, 'end_time': 311.405, 'duration': 58.635, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 188}
# to get it out of the way, here is an architectural diagram for the relatively simple near shallow architecture pattern that we're using It doesn't seem like there are many neurons in a network of this type, and that's because all of the activations are softmax Which means despite the fact that the Umatrix, for example is an entire layer, it's really just going through a single prediction nonlinearity the softmax function you can think about this as essentially a threelayer network that might be creating an encoderdecoder kind of design Likewise, the difference in presentation here ov selfattention, which is parameterized by the matrix W here, is intending to show how a whether you consider it the query or the key one vector is the pivot for the comparison that will produce the feature weights which is then fed forward in this model through W This is the case for standard selfattention, too In other words, you can reduce it to a biprediction diagram in this way where a gray vector such as is depicted here is that pivot
# {'video_id': 'zL9B3eXq0gY', 'title': 'Stanford CS25: V4 I Transformers that Transform Well Enough to Support Near-Shallow Architectures', 'course': 'CS25_Transformers', 'start_time': 393.71, 'end_time': 467.13, 'duration': 73.42, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 234}
# The attention distribution coming out of the W matrix and the softmax function is indicated by the vertical red bar there, which weights the block of vectors in black That includes the pivot vector in gray which is then passed through a feedforward layer often called the values of a standard selfattention matrix Since we use U as a way to reduce the dimensionality of the prediction that we're trying to make, we then feed that forward through another layer and then to output And that's essentially the relative shallowness that we're talking about here W is a selfattention matrix, which means there's really only two layers in effect here And the activation functions are strange And you might wonder, for example why we're using a different activation function to softmax instead of any of the dimensionally independent activation functions like a logistic function or anything else And that's because we have additional insight into the softmax function and the parameters that it optimizes, which is very useful let's talk about those vectors first though before we get to layer initialization
# {'video_id': 'zL9B3eXq0gY', 'title': 'Stanford CS25: V4 I Transformers that Transform Well Enough to Support Near-Shallow Architectures', 'course': 'CS25_Transformers', 'start_time': 467.13, 'end_time': 544.75, 'duration': 77.62, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 235}
# ...
# {'video_id': 'eLAq8yzvu8Q', 'title': 'Generative AI for Healthcare (Part 1): Demystifying Large Language Models', 'course': 'CS336_GPU_TPU', 'start_time': 1487.56, 'end_time': 1560.46, 'duration': 72.9, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 240}
# In a little bit, Shivam will walk us through how the static embeddings were determined But for now, here's the key thing to keep in mind Static embeddings are learned during the very expensive pretraining phase of the language model When you train a new model, it starts out with, essentially, completely random embeddings, just noise But over the course of the training as the model progresses and processes vast amounts of text these embeddings get collectively and iteratively refined and adjusted again and again until they settle into stable positions that reflect meaningful language patterns By the end of the training, these vectors become the model's fixed starting point for each token This also means that once a model is trained every time it sees a token, let's say the word patient, it retrieves the same vector regardless of where or how that word appears But this is a problem for us The word patient in room three is something very different than please be patient with me how does the model adapt to this Now, this is where the transformer architecture comes
# {'video_id': 'eLAq8yzvu8Q', 'title': 'Generative AI for Healthcare (Part 1): Demystifying Large Language Models', 'course': 'CS336_GPU_TPU', 'start_time': 1629.74, 'end_time': 1690.71, 'duration': 60.97, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 239}
# in, specifically a mechanism called selfattention And this isn't just a technical detail Selfattention is literally the key breakthrough that made all modern language models possible As each token's embedding moves through the multiple layers of this transformer, the model begins to recalculate and update that vector layer by layer It uses selfattention to weigh the importance of other tokens in the sentence, dynamically adjusting the representation of each word based off of the surrounding context And by the end of this process, the original static embedding has been transformed into what we now call a contextaware embedding, one that doesn't just reflect the standalone meaning of the token, but now also encodes within it how it fits into the meaning of the entire sentence, or the paragraph or even the whole document This transformation process happens for every single token in the entire input prompt And by the end, you have a fully contextualized embedding for every single token in the sequence And from here, the model can finally use these to generate an output
# {'video_id': 'eLAq8yzvu8Q', 'title': 'Generative AI for Healthcare (Part 1): Demystifying Large Language Models', 'course': 'CS336_GPU_TPU', 'start_time': 1690.71, 'end_time': 1752.62, 'duration': 61.91, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 228}
# might look like And with every new token, the model builds more context for itself But that context is shaped entirely by what it just generated And here's why this matters In models like these, the output isn't just the answer It also becomes a part of the reasoning path The model doesn't plan it's answer in advance It doesn't think and then speak It thinks by speaking That means that if we want the model to arrive at better answers, especially for complex problems we need to prompt it to write out it's reasoning step by step This is a super important concept to grasp if you want to understand how LLMs think and is the foundation or at least was the foundation for something called chain of thought, which we'll talk about later and is also what forms the basis for newer reasoning models that have been released And let's imagine, visually, what an LLM navigating through a vector space might look like Here is a very basic twodimensional vector space And the purple zone here represents the solution space
# {'video_id': 'eLAq8yzvu8Q', 'title': 'Generative AI for Healthcare (Part 1): Demystifying Large Language Models', 'course': 'CS336_GPU_TPU', 'start_time': 1933.38, 'end_time': 1994.505, 'duration': 61.125, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
# or the region of the vector space where a good, accurate, or desirable answer might live As the LLM breaks down the prompt into tokens and embeddings, and as the output is generated each additional token is another opportunity to inform the model about the context and another opportunity to guide the output towards the ideal solution space until you finally reach a correct or acceptable answer Now, of course, for complex tasks it's actually quite challenging to get this right on your first attempt, and your outputs might look something like this, or like this, or even like this which is exactly why learning the basics and best practices of effective prompting are so important And so to go back to our earlier question how is it possible that an LLM can manipulate ideas and concepts If we ask an LLM a question, something like this this is what we might see on our screens But really, what's happening behind the scenes is something like this if we ask ourselves, how do humans convey abstract ideas
# {'video_id': 'eLAq8yzvu8Q', 'title': 'Generative AI for Healthcare (Part 1): Demystifying Large Language Models', 'course': 'CS336_GPU_TPU', 'start_time': 1994.505, 'end_time': 2057.469, 'duration': 62.964, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 230}
# a fun fact, GPT is now open source which means you can actually run it locally on your own machine that's exactly what I did I gave it a question I might ask as a hospitalist, which antibiotics are firstline for treating inpatient communityacquired pneumonia, assuming no risk factors And here's what GPT1 gave us I don't the woman said, but I'll ask Good Now, what else do about this plague Helpful Not really But it makes sense given the training data it was trained exclusively on books And I'm sure, somewhere, there was something about a plague associated with pneumonia or at least the vector space concepts were related somehow it understandably generated this, which is essentially an excerpt from a book The following year, they released GPT2 and made a bunch of tweaks in the back end They increased the number of parameters from 117 million to 1.5 billion, so about a 13fold increase They also changed the training data Not only do they scale it up to around 40 gigabytes of text but they also changed the foundational source
# {'video_id': 'eLAq8yzvu8Q', 'title': 'Generative AI for Healthcare (Part 1): Demystifying Large Language Models', 'course': 'CS336_GPU_TPU', 'start_time': 2289.98, 'end_time': 2352.51, 'duration': 62.53, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
# retrieval augmented generation is one way to handle this, such as it could reduce the hallucination by using the actual relevant reference It also address the citation because it knows where this reference is coming from And then this will allow you as an application develop or a system developer to prepare systems that you could use your own proprietary data set or the text And then you could use good use of small number of context links because it only select relevant data set how it works is you could preindex your own data set or your own text by turn them into smaller chunk, chunk of text, and then convert them into an embedding space using embedding model, and then stage them as part of your database or vector database And then when the request or query came you could turn this query into embedding space that you could do nearest neighboring search and then select top K relevant information, relevant chunk text chunk, and then place them as part of your prompt Some of the slide that we see previously
# {'video_id': 'kJLiOGle3Lw', 'title': 'Stanford Webinar - Agentic AI: A Progression of Language Model Usage', 'course': 'CS336_GPU_TPU', 'start_time': 1412.19, 'end_time': 1512.45, 'duration': 100.26, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 237}
# And the opponent is going to play the exact same way that the first agent did using the same offline learn neural network, same MCTS setup it builds up the search tree and then plays an action sampled from that policy And this process of the selfplay just continues until the end game is reached And at that point, we have this indication of who won the game that Z variable is telling us which of the agents won now we have this self play demonstration And we can use this then to update the offline learn neural network how that network set up was basically it takes as input the raw board state, so that S1 and then it outputs two things the first output is this vector of action probabilities that's the P1 And that's telling you the probability of selecting each action And then the second output is the value estimate And the value estimate there is just mapping to the probability that the current agent ends up winning the game that's this idea of what is, the value
# {'video_id': 'iLMzsV0JOHk', 'title': 'Stanford AA228/CS238 Decision Making Under Uncertainty I Online Planning and Policy Search', 'course': 'CS336_GPU_TPU', 'start_time': 3829.42, 'end_time': 3889.53, 'duration': 60.11, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
# And so we're going to have this vector of parameters here theta we're just going to have theta 1 to theta n we have n parameters here These could be the weights and biases of a neural network They could just be the parameters of a linear function or any type of function we just have these parameters here And now we're representing our policy, pi And we're going to write it as pi theta just to denote that it's parameterized by this vector of parameters we're still taking in a state and we're still outputting an action to take from that particular state It's just now we're representing this policy function or distribution by these parameters, theta what's going to happen now is that we want to basically figure out how should we update these parameters in such a way that we improve our policy That's where we're going with this And just like what we saw before was that we could use these rollouts to estimate the utility of a particular policy now when we talk about the utility of our policy
# {'video_id': 'iLMzsV0JOHk', 'title': 'Stanford AA228/CS238 Decision Making Under Uncertainty I Online Planning and Policy Search', 'course': 'CS336_GPU_TPU', 'start_time': 4331.64, 'end_time': 4394.79, 'duration': 63.15, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 239}
# we're going to say the utility here of following policy pi theta And we can equivalently write this as just u of theta And you'll often see it just dropped like that because really, what you're talking about is the utility of the parameters of that policy we're concerned about improving those parameters And we can equivalently do the same idea here of the policy rollouts and approximate this utility just using m policy rollouts and getting those rollout trajectories here with a current policy parameterization we have some current policy parameter vector here we're then going to perform m policy rollouts using that policy and then get this estimate of the utility of those specific policy parameters same idea, just now using a different policy set up here the first method here for policy search that we're going to be talking about is local search And the way that local search works is we start in this example We have a policy with two parameters, theta 1 and theta 2 And the current policy parameters
# {'video_id': 'iLMzsV0JOHk', 'title': 'Stanford AA228/CS238 Decision Making Under Uncertainty I Online Planning and Policy Search', 'course': 'CS336_GPU_TPU', 'start_time': 4394.79, 'end_time': 4465.72, 'duration': 70.93, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 228}
# And so some of the drawbacks here is that we have to use m rollouts for each of these candidate points we have to n candidate points and performing m rollouts for each one of those if you have a really large parameterization you have a billion parameters in your policy then that's going to be quite intensive to do And it also requires setting that initial alpha step size that you're using that now becomes your parameter to play with And so that's what brings us to the cross entropy method And the cross entropy method seeks to improve on the weaknesses of local search by using a search distribution that we are representing by this p theta of psi here And so, again, this is still just our policy vector of parameters But now we have this other set of parameters here which parameterize our search distribution if we're using a Gaussian distribution this is just the mean and covariance of the Gaussian distribution All right And what we're saying then is that our policy parameters
# {'video_id': 'iLMzsV0JOHk', 'title': 'Stanford AA228/CS238 Decision Making Under Uncertainty I Online Planning and Policy Search', 'course': 'CS336_GPU_TPU', 'start_time': 4579.71, 'end_time': 4644.41, 'duration': 64.7, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 231}
# otherwise we'd have a very simple policy Gradient u of theta is going to have this form for every theta I, we're going to have a partial derivative Let's say that we have n of these parameters theta For the example that I just showed you, n would be 2 And this is going to give us an n by 1 vector And before I go on, I wanted to make a note This portion of the lecture and also probably your portion too is pretty calculus heavy And depending on your background you may have done that more or less recently I don't want you to feel like calculusrelated questions are less legitimate than questions about material that maybe you've only seen in this course I definitely had to look up stuff preparing for this And if the calculus is a sticking point please say something We want you to feel good about every step that we're taking the first method is something that you probably saw in early calculus And that's going to be finite differences
# {'video_id': 'PgPNfPhG4Wc', 'title': 'Stanford AA228/CS238 Decision Making Under Uncertainty I Policy Gradient Estimation & Optimization', 'course': 'CS336_GPU_TPU', 'start_time': 229.14, 'end_time': 306.946, 'duration': 77.806, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 231}
# you might be wondering what this e here is This is a standard basis vector And this index indicates the position at which we have a 1 All other positions are going to be 0 here, we would have a 1, followed by n minus 1, 0s and so on And the reason that we're doing that is that we're only applying this difference delta to one parameter at a time And so this is going to give us an n by 1 vector with a simple estimate of the gradient of e of theta around some point Does anyone have questions here How do we feel about the first one What's u again Great question U is the utility of theta And we get u of theta, as Josh mentioned previously by using rollout simulations this is something that can impact this method is that depending on the variance of u of theta it may take a lot of rollouts to get a good estimate And the book talks about some techniques that you could practically use to mitigate the potential
# {'video_id': 'PgPNfPhG4Wc', 'title': 'Stanford AA228/CS238 Decision Making Under Uncertainty I Policy Gradient Estimation & Optimization', 'course': 'CS336_GPU_TPU', 'start_time': 406.71, 'end_time': 480.46, 'duration': 73.75, 'source': 'stanford_youtube', 'chunk_type': 'knowledge_unit', 'token_count': 236}
